# %% [markdown]
# # <center><font color=red size=36>2. COMPONENTS OF A PYTHON PROGRAM<font>

# %% [markdown]
# ![Screen%20Shot%202022-03-18%20at%209.37.45%20PM.jpg](attachment:Screen%20Shot%202022-03-18%20at%209.37.45%20PM.jpg)

# %% [markdown]
# # Literals, Variables & Constants

# %% [markdown]
# >>### Variables are memery references of values. Variables can change someone within the program.
# >>### Constants cannot change within the program.
# >>> __*Pi = 3.14 is a constant.*__ <br>
# >>> <b>*Company_registration_number = 76686 is a constant.* <b>
# >> ### Literals are the values assigned to variables and constants. When we write x = "Hello", "Hello" is a literal while x is a variable: https://youtu.be/zbhUFGxF3-I

# %% [markdown]
# # Identifiers

# %% [markdown]
# >## They are the names given to objects (variales, constants, class, functions)
# >>## They must not start with a number.
# >> ## They must not contain special characters ($,#,@,etc.)

# %% [markdown]
# # Constants
# >## PEPS Recommends using uppercase.
# >## Also good practice to have a separate file of constants (constants.py) andthen import it to use.

# %% [markdown]
# # Reserved words

# %%
import keyword
print (keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Comments

# %%
# This is a single line comment

# %% [markdown]
# ### Multiline comments

# %% [markdown]
# https://youtu.be/NWnW-GUoRoY
#
# https://youtu.be/ZmpdfseDGUQ
