# %% [markdown]
# # <center><FONT COLOR=RED size=36>13. FILES IN PYTHON<FONT>

# %% [markdown]
# # Openning file, Reading, Writing into, and closing a file

# %% [markdown]
# ![Screen%20Shot%202022-04-06%20at%203.45.02%20PM.jpg](attachment:Screen%20Shot%202022-04-06%20at%203.45.02%20PM.jpg)

# %% [markdown]
# ![Screen%20Shot%202022-04-07%20at%206.51.25%20AM.jpg](attachment:Screen%20Shot%202022-04-07%20at%206.51.25%20AM.jpg)

# %% [markdown]
# ![Screen%20Shot%202022-04-07%20at%206.51.40%20AM.jpg](attachment:Screen%20Shot%202022-04-07%20at%206.51.40%20AM.jpg)

# %% [markdown]
# ## Open and read

# %% [markdown]
# open("File name or directory.extension","mode=r for read or w for write", "buffering--optional")

# %%
# read the file Python_file.txt  in the same directory as this notebook


f = open("Python_File.txt","r")

f.name                 # returns name of file
# Out:
# 'Python_File.txt'

# %%
f.mode        # gives the state in which file is open:r=read, w=write, etc.
# Out:
# 'r'

# %%
f.read()        # reads the content of the file from the beginning
# Out:
# ''

# %%
f.close()          # closes the file. Always close in order to save memory

# %%
f.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yn/bgdm1mhs37b6r_38shjd1v5c0000gn/T/ipykernel_11205/3059900045.py in <module>
# ----> 1 f.read()
#
# ValueError: I/O operation on closed file.

# %%
f1 = open("Python_File.txt","r")

f1.read(10)    # reads the first 10 characters
# Out:
# 'L1: What i'

# %%
f1.readline()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/yn/bgdm1mhs37b6r_38shjd1v5c0000gn/T/ipykernel_11205/3592056824.py in <module>
# ----> 1 f1.readline()
#
# NameError: name 'f1' is not defined

# %%
f.readlines(5)
# Out:
# []

# %%
f.tell() # tells the position of the cursor in terms of bytes
# Out:
# 622

# %%
f.seek(500,622) # this moves the cursor 500 bytes from byte number 622
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yn/bgdm1mhs37b6r_38shjd1v5c0000gn/T/ipykernel_60620/2595313890.py in <module>
# ----> 1 f.seek(500,622) # this moves the cursor 500 bytes from byte number 622
#
# ValueError: invalid whence (622, should be 0, 1 or 2)

# %%
ft = open("Python test file2.txt","w")
print("Enter text; end with #: ")

while text != "#":
    text = input()
    ft.write(text + "\n")
ft.close()
# Out:
# Enter text; end with #:
# Hey you!
# Hey you too!
# How are you?
# I'm fine, thanks. And you?
# Me too
# You know. I love you very much!
# I love you even more!
# Are you sure?
# Yes, of course you know this
# Yes, I do. Thank you for loving me.
# Thank you too for your love
# Ok. Bye
# Bye
# #

# %%
f2 = open("built-in functions in Python.pdf","r")

f2.mode
# Out:
# 'r'

# %%
f2.name
# Out:
# 'built-in functions in Python.pdf'

# %%
f2.tell()
# Out:
# 1475590

# %%
f2.seek
# Out:
# <function TextIOWrapper.seek(cookie, whence=0, /)>

# %%
f2.closed
# Out:
# False

# %%
f2.close()

# %%
f2.closed
# Out:
# True

# %% [markdown]
# # Open and write
#  - NB: with w mode, if the file is text file with text, the text will be cleared

# %%
# open and write 3 lines of text 
with open("Python_File1.txt","w") as fw:
    fw.write("This is line1 \n This is line 2 \n This is line 3")

# %%
# check whether the lines are written

with open("Python_File1.txt") as fr:
    print(fr.read())
# Out:
# This is line1
#  This is line 2
#  This is line 3

# %%
with open

# %% [markdown]
# # Open and append text
#  - this writes to file without losing the previously written text

# %%
with open("Python_File.txt","a") as fa:
    fa.write("\n This is line A \n This is line B \n This is line C")

# %%
with open("Python_File.txt","r") as fa:
    print(fa.read())
# Out:
# L1: What is Lorem Ipsum?
# L2: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# L3: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# L4: It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
# L5: It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.This is line A
#  This is line B
#  This is line CThis is line A
#  This is line B
#  This is line C
#  This is line A
#  This is line B
#  This is line C

# %%
fl.close
# Out:
# <function TextIOWrapper.close()>

# %% [markdown]
# ## Using "with" to open a file is better because it automatically closes the file

# %% [markdown]
# ## Here is the syntax

# %% [markdown]
# ![Screen%20Shot%202022-04-06%20at%203.51.45%20PM.jpg](attachment:Screen%20Shot%202022-04-06%20at%203.51.45%20PM.jpg)

# %% [markdown]
# ## Here is an example

# %% [markdown]
# ![Screen%20Shot%202022-04-06%20at%2012.36.06%20AM.jpg](attachment:Screen%20Shot%202022-04-06%20at%2012.36.06%20AM.jpg)

# %%
with open("Python_File.txt","r") as f1:
    file_stuff = f1.read()
    print(file_stuff)
# Out:
# What is Lorem Ipsum?
# L1: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# L2: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# L3: It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
# L4: It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

# %%
print(f1.closed)
# Out:
# True

# %%
print(file_stuff)
# Out:
# What is Lorem Ipsum?
# L1: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# L2: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# L3: It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
# L4: It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

# %%
with open("Python_File.txt","r") as f2:
    file_cont = f2.read()
    
print(file_cont)
# Out:
# What is Lorem Ipsum?
# L1: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
# L2: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
# L3: It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
# L4: It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

# %%
with open("Python_File.txt","r") as f3:
    print(f3.readlines(4))
# Out:
# ['What is Lorem Ipsum?\n']

# %%
with open("Python_File - Copy.txt","r") as f5:
    for line in f5:
        print(line)
# Out:
# What is Lorem Ipsum?
#
# L1: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
#
# L2: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
#
# L3: It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
#
# L4: It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

# %%
# we can read the first 16 characters, then the next 5 characters, then the next 10 characters using read()

with open("Python_File.txt","r") as f6:
    print(f6.read(16))
    print(f6.read(5))
    print(f6.read(10))
# Out:
# L1: What is Lore
# m Ips
# um?
# L2: Lo

# %%
# Using readlines, we can read one line each time in the file.
# unlike the method read(), readline() can only read one line at most.
# passing readline() the first time reads the first line, the second time reads the second line, etc.
# to read a specified line, use readlines(line number) instead. readlines saves the specific line text in a list.

with open("Python_File.txt") as file4:
    print(file4.readline())
    print(file4.readline())
    print(file4.readlines(3))
# Out:
# L1: What is Lorem Ipsum?
#
# L2: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
#
# ["L3: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. \n"]

# %%
# We can use a loop to iterate through the lines in the file

with open("Python_File.txt") as file5:
    i=0
    for line in file5:
        print("Iteration ",str(i), ": ", line)
        i +=1
# Out:
# Iteration  0 :  L1: What is Lorem Ipsum?
#
# Iteration  1 :  L2: Lorem Ipsum is simply dummy text of the printing and typesetting industry.
#
# Iteration  2 :  L3: Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.
#
# Iteration  3 :  L4: It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.
#
# Iteration  4 :  L5: It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.

# %%
# We can check the type of the file

file4 = open("Python_File.txt")
type(file4)
# Out:
# _io.TextIOWrapper

# %%
file4.closed
# Out:
# False

# %%
file4.close()

# %%
file4.closed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/yn/bgdm1mhs37b6r_38shjd1v5c0000gn/T/ipykernel_11205/74820714.py in <module>
# ----> 1 file4.closed
#
# NameError: name 'file4' is not defined

# %% [markdown]
# # Checking if a file is present or not

# %%
# os is an inbuilt module (like math module) that is imported to check for the presence odf a file

import os

if os.path.isfile("Python_file.txt"):
    print("File exists")
else:
    print("File does not exist")
# Out:
# File exists

# %% [markdown]
# # NAMING CONVENTIONS (RECOMMENDED)

# %% [markdown]
# Naming Styles
# The table below outlines some of the common naming styles in Python code and when you should use them:
#
# Type	Naming Convention	Examples
#
#  - Function---> Use a lowercase word or words. Separate words by underscores to improve readability.	function, my_function
#  - Variable---> Use a lowercase single letter, word, or words. Separate words with underscores to improve readability.	x, var, my_variable.
#  - Class---> Start each word with a capital letter. Do not separate words with underscores. This style is called camel case.	Model, MyClass.
#  - Method---> Use a lowercase word or words. Separate words with underscores to improve readability.	class_method, method.
#  - Constant---> Use an uppercase single letter, word, or words. Separate words with underscores to improve readability.	CONSTANT, MY_CONSTANT, MY_LONG_CONSTANT.
#  - Module---> Use a short, lowercase word or words. Separate words with underscores to improve readability.	module.py, my_module.py
#  - Package---> Use a short, lowercase word or words. Do not separate words with underscores.	package, mypac
#
#
#  ALSO SEE [THIS ARTICLE](https://www.analyticsvidhya.com/blog/2020/07/python-style-guide/)
